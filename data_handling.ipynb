# %%
import numpy as np
import pandas as pd

data = pd.read_csv("sim_output/time_series.csv")
data.sample(5)
# Out:
#       episode_id    t   dt    true_x    true_y  true_theta     est_x  \
# 1915          16   73  0.1  4.387338 -4.963389   -0.754745  4.311750
# 1433          12  132  0.1 -6.587501 -5.662094   -3.134737 -6.546135
# 2483          21   51  0.1 -3.804152 -2.572435   -2.888297 -4.003168
# 1345          12   44  0.1 -2.293010 -2.961416   -2.592218 -2.294889
# 2132          19   65  0.1 -1.722283  6.648533    1.843817 -0.918127
#
#          est_y  est_theta    goal_x  ...       u_w  n_obs  trace_pose_cov  \
# 1915 -4.779125  -0.690083  4.902176  ...  0.088634      4        0.087337
# 1433 -5.598218  -3.118734 -6.569021  ... -0.009796      0        0.163704
# 2483 -1.886545  -2.974785 -7.230474  ...  0.063921      6        0.064662
# 1345 -2.798214  -2.566128 -6.569021  ... -0.012154      6        0.069990
# 2132  6.732419   1.797138 -1.157503  ... -0.050726      1        0.125843
#
#       pos_uncertainty  loc_error  true_dist_to_goal  est_dist_to_goal  \
# ...
